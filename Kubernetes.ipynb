# %% [markdown]
# 1. Kubernetes Setup: Set up a local Kubernetes cluster using Minikube or a
# managed Kubernetes service ? (e.g., GKE, EKS)

# %% [raw]
# curl -sfL https://get.k3s.io | sh -
# # Check for Ready node, takes ~30 seconds
# sudo k3s kubectl get node

# %% [markdown]
# 2. Application Deployment: Deploy a simple application to your Kubernetes
# cluster?

# %% [raw]
# kubectl create deployment server2 --image nginx

# %% [markdown]
# 3. Resource Management: Practice managing Kubernetes resources like
# Pods, Services, and Deployments?

# %% [raw]
# PODS
# kubectl run mypod --image=nginx
#
# kubectl get pods
#
# kubectl describe pod mypod
#
# kubectl delete pod mypod
#
#
# SERVICES
# kubectl create deployment webserver --image=nginx --replicas=3
#
# kubectl expose deployment webserver --port=80 --type=NodePort
# kubectl get services
#
# kubectl describe service webserver
#
# kubectl get svc webserver
#
# DEPLOYMENTS
# kubectl get deployments
#
# kubectl scale deployment webserver --replicas=5
#
# kubectl get pods
#
# kubectl scale deployment webserver --replicas=2
#
# kubectl rollout status deployment webserver
# kubectl set image deployment/webserver nginx=nginx:1.25
#
# kubectl rollout history deployment webserver
#
# kubectl rollout undo deployment webserver

# %% [markdown]
# 4. Helm Charts: Use Helm to package and deploy applications on
# Kubernetes?

# %%
HELM INSTALL
curl https://raw.githubusercontent.com/helm/helm/main/scripts/get-helm-3 | bash

helm version

HELM CHART CREATE
helm create myapp

ls -la myapp/

CHART DEPLOY
helm install myapp-release myapp/

helm list

helm status myapp-release

EXISTING CHART USE KARO
helm repo add bitnami https://charts.bitnami.com/bitnami

helm repo update

helm search repo nginx

helm install my-nginx bitnami/nginx

HELM MANAGEMENT
helm list

helm upgrade myapp-release myapp/

helm uninstall myapp-release

helm list -A


BONUS: Quick Verification Commands

kubectl get all

kubectl get all -n default

kubectl get all -A

kubectl cluster-info

kubectl get nodesRetryClaude can make mistakes. Please double-check respo
